# %% [markdown]
# # Homework 4 Assignment 1:
#
# Directions from Dr. Bianco : https://github.com/fedhere/PUI2018_fb55/tree/master/HW4_fb55
#
# And the skeleton notebook is also from Dr. Bianco (@fedhere)
#
# -  GENERATE  100 samples of different sizes N (N>10 & N<2000) from each of 5 different distributions (500 samples in total),
#  _all with the same population mean_. Include a _Normal_, a _Poisson_, a _Binomial_, a _Chi-Squared_ distribution, and 1 more of your choice.
# -  For each sample plot the sample mean (dependent var.) against the sample size N (independent var.) (if you want you can do it with the sample standard deviation as well).
# -  Describe the behavior you see in the plots in terms of the law of large numbers.
# -  PLOT the distributions of all sample means (together for all distributions). _Mandatory_: as a histogram. _Optional_: in any other way you think is convincing
#  Extra Credit: FIT a gaussian to the distribution of means

# %%
# import libraries
from __future__ import print_function
import pylab as pl
import seaborn
from scipy.optimize import curve_fit, minimize
import numpy as np
    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
# seeding for reproducibility
np.random.seed(303)

# %% [markdown]
# ### which mean to give it

# %%
# This is the sample mean
mymean = 100

# %% [markdown]
# ### what is the size

# %%
mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [750 281 550 810 621 435 187 360 288 587 655 145  98 553 668 221  23 125
#  743 538  82 758  30 538 998  10 951  64 406 512 309 667 506 214  74 420
#  359 206 304 708 938 907 990 774 683 819 931 821 269 822 899 142 921 186
#  711  85 702 201 810 227 648 295 184 812 676  47 904 624 808 506 150  69
#  648 462 221 412  53 845 718 722 732 684 289 140 769 879 857 487  21 505
#  975 885 304  61 127 163 297 760 132  89] (100,)

# %%
# create an empty dictionary

# md is the main dictionary
md = {}

# %%
# the chi sq distribution takes the number of degrees of freedom, which luckily is the same as the mean!
df = mymean

# %% [markdown]
# ### Then lets look at the numpy random sampling package to see how I create the distribution
# http://docs.scipy.org/doc/numpy/reference/routines.random.html
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.chisquare.html#numpy.random.chisquare

# %% [markdown]
# ## 1. Normal Distribution

# %%
##your code here...

## starting with a single gausian distribution
np.random.normal(mymean, 1, 100)

pl.hist(np.random.normal(mymean, 1, 100), bins = 30)
pl.ylabel('N')
pl.xlabel('X')
pl.title('')
# Out:
# Text(0.5,1,'')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 1: Normal distribution with mean set to 100, and N = 100

# %%
print("Normal Mean: %.2f, standard deviation: %.2f" % ((np.random.normal(mymean, 1, 100)).mean(), +
                                                       (np.random.normal(mymean, 1, 100)).std()))
# Out:
# Normal Mean: 100.03, standard deviation: 1.04

# %%
## Now scale this to 100 Normal Distributions

## append into the md dictionary with the Normal Gaussian distribution
md['gaus'] = {}

## using a loop to create 100  samples of different N sizes normal distribution

for i in mysize:
    md['gaus'][i] = np.random.normal(mymean, 1, i)
    
## create the means key for the gaussian distribution for plotting
md['gaus']['means'] = {}

axgaus_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for i in md['gaus']:
    if not type(i) == str:
        md['gaus']['means'][i] = md['gaus'][i].mean()
        #and plot it
        axgaus_mu_n.plot(i, md['gaus']['means'][i], 'o')
        axgaus_mu_n.set_xlabel('sample size', fontsize=18)
        axgaus_mu_n.set_ylabel('sample mean', fontsize=18)
        axgaus_mu_n.set_title('Normal/Gaussian', fontsize=18)
        axgaus_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 2: Scatterplot for the normal distribution for sample size and sample mean. Like in accordance with the central limit theorem- the larger the sample size, the closer the sample means are to approaching the population mean.

# %%
gaus_means = list(md['gaus']['means'].values())

pl.figure(figsize = (10,10))
pl.hist(gaus_means, bins = 30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
# Out:
# Text(0,0.5,'N')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 3: This is a histogram showing that frequency of the sample means and how it hovers around 100 which is what was set in the beginning as the variable mymean for this normal distribution.

# %% [markdown]
# # 2. Poisson distribution

# %%
##your code here...

# ['pois']

## starting with a single poisbson distribution
np.random.poisson(mymean, 100)

pl.hist(np.random.poisson(mymean, 100), normed=True)
pl.ylabel('N')
pl.xlabel('X')
pl.title('')
# Out:
# Text(0.5,1,'')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 4: Poisson distribution with mean set to 100, and N = 100

# %%
print("Poisson Mean: %.2f, standard deviation: %.2f" % ((np.random.poisson(mymean, 100)).mean(), +
                                                        (np.random.poisson(mymean, 100)).std()))
# Out:
# Poisson Mean: 100.40, standard deviation: 9.42

# %%
## Now scale this to 100 Poisson Distributions

## append into the md dictionary with the Normal Gaussian distribution
md['pois'] = {}

## using a loop to create 100  samples of different N sizes normal distribution

for i in mysize:
    md['pois'][i] = np.random.poisson(mymean, i)
    
## create the means key for the gaussian distribution for plotting
md['pois']['means'] = {}

axpois_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for i in md['pois']:
    if not type(i) == str:
        md['pois']['means'][i] = md['pois'][i].mean()
        #and plot it
        axpois_mu_n.plot(i, md['pois']['means'][i], 'o')
        axpois_mu_n.set_xlabel('sample size', fontsize=18)
        axpois_mu_n.set_ylabel('sample mean', fontsize=18)
        axpois_mu_n.set_title('Poisson', fontsize=18)
        axpois_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 5: Scatterplot for the poisson distribution for sample size and sample mean. Like in accordance with the central limit theorem- the larger the sample size, the closer the sample means are to approaching the population mean.

# %%
pois_means = list(md['pois']['means'].values())

pl.figure(figsize = (10,10))
pl.hist(pois_means, bins = 30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
# Out:
# Text(0,0.5,'N')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 6: This is a histogram showing that frequency of the sample means and how it hovers around 100 which is what was set in the beginning as the variable mymean for this poisson distribution.

# %% [markdown]
# # 3. Binomial distribution

# %%
##your code here...
#  ['binomial']

## starting with a single poisson distribution
np.random.binomial(mymean*2, .5, 100)

pl.hist(np.random.binomial(mymean*2, .5, 100))
pl.ylabel('N')
pl.xlabel('X')
pl.title('')
# Out:
# Text(0.5,1,'')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 7: Binomial distribution with number of trials set to 200, probability set to 0.5, for a mean around 100 and N = 100

# %%
print("Binomial Mean: %.2f, standard deviation: %.2f" % ((np.random.binomial(mymean*2, .5, 100)).mean(), +
                                                         (np.random.binomial(mymean*2, .5, 100)).std()))
# Out:
# Binomial Mean: 100.53, standard deviation: 6.61

# %%
## Now scale this to 100 binomial Distributions

## append into the md dictionary with the binomial distribution
md['binomial'] = {}

## using a loop to create 100  samples of different N sizes normal distribution

for i in mysize:
    md['binomial'][i] = np.random.binomial(mymean*2, 0.5, i)
    
## create the means key for the gaussian distribution for plotting
md['binomial']['means'] = {}

axbinomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for i in md['binomial']:
    if not type(i) == str:
        md['binomial']['means'][i] = md['binomial'][i].mean()
        #and plot it
        axbinomial_mu_n.plot(i, md['binomial']['means'][i], 'o')
        axbinomial_mu_n.set_xlabel('sample size', fontsize=18)
        axbinomial_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinomial_mu_n.set_title('Binomial', fontsize=18)
        axbinomial_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 8: Scatterplot for the binomial distribution for sample size and sample mean. Like in accordance with the central limit theorem- the larger the sample size, the closer the sample means are to approaching the population mean.

# %%
binomial_means = list(md['binomial']['means'].values())

pl.figure(figsize = (10,10))
pl.hist(binomial_means, bins = 30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
# Out:
# Text(0,0.5,'N')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 9: This is a histogram showing that frequency of the sample means and how it hovers around 100 which is what was set in the beginning as the variable mymean for this binomial distribution.

# %% [markdown]
# # 4. Chi-Squared Distribution

# %% [markdown]
# ### Using a dictionary to host all the different types of distributions.

# %%
#distributions
distributions = ['chisq']

# %%
# md is an empty disctionary
md['chisq'] = np.random.chisquare(df, size=100)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# Text(0.5,0,'x')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 10: Chi sq distribution: df = 100, N=100

# %% [markdown]
# ### let numpy calculate what the mean and stdev of this distribution are

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 102.31, standard deviation: 13.46

# %% [markdown]
# ### Now let's do it for 100 Chisq distributions
# we want distributions of different sizes (all integers between 10 and 2000)

# %%
# overwrite the md dictionary
md['chisq'] = {}

# using a loop to append into the dictionary
for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
    
# save the means for plotting later
md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 11: Scatterplot for the chi-squared distribution for sample size and sample mean. Like in accordance with the central limit theorem- the larger the sample size, the closer the sample means are to approaching the population mean.

# %%
chisq_means = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(chisq_means,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
# Out:
# Text(0,0.5,'N')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 12: This is a histogram showing that frequency of the sample means and how it hovers around 100 which is what was set in the beginning as the variable mymean for this chi-squared distribution.

# %% [markdown]
# # 5. Lognormal Distribution

# %%
##your code here...

# distributions = ['lnorm']

## starting with a single lnorm distribution
np.random.lognormal(4.605, .1, 100)

pl.hist(np.random.lognormal(4.605, .1, 100))
pl.ylabel('N')
pl.xlabel('X')
pl.title('')
# Out:
# Text(0.5,1,'')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 13: Lognormal distribution for N = 100 and mean set to 4.605 for the underlying normal distribution

# %%
print("Lognormal Mean: ", str(np.random.lognormal(4.605, .1, 100).mean()))
# Out:
# Lognormal Mean:  100.277938639

# %%
## Now scale this to 100 lognormal Distributions

## append into the md dictionary with the lognormal distribution
md['lnorm'] = {}

## using a loop to create 100  samples of different N sizes lognormal distribution

for i in mysize:
    md['lnorm'][i] = np.random.lognormal(4.605, 0.1, i)
    
## create the means key for the gaussian distribution for plotting
md['lnorm']['means'] = {}

axlnorm_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for i in md['lnorm']:
    if not type(i) == str:
        md['lnorm']['means'][i] = md['lnorm'][i].mean()
        #and plot it
        axlnorm_mu_n.plot(i, md['lnorm']['means'][i], 'o')
        axlnorm_mu_n.set_xlabel('sample size', fontsize=18)
        axlnorm_mu_n.set_ylabel('sample mean', fontsize=18)
        axlnorm_mu_n.set_title('Lognormal', fontsize=18)
        axlnorm_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 14: Scatterplot for the lognormal distribution for sample size and sample mean. Like in accordance with the central limit theorem- the larger the sample size, the closer the sample means are to approaching the population mean.

# %%
lnorm_means = list(md['lnorm']['means'].values())

pl.figure(figsize = (10,10))
pl.hist(lnorm_means, bins = 30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
# Out:
# Text(0,0.5,'N')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 15: This is a histogram showing that frequency of the sample means and how it hovers around 100 which is what was set in the beginning as the variable mymean for this lognormal distribution.

# %% [markdown]
# # 6. PLOT the distributions of all sample means (together for all distributions)

# %%
pl.figure(figsize = (10,10))
pl.hist(gaus_means, bins = 30, label = 'Gaussian', alpha = 0.5, align = 'mid') # Normal Distribution Means
pl.hist(pois_means, bins = 30, label = 'Poisson', alpha = 0.5, align = 'mid') # Poisson Distribution Means
pl.hist(binomial_means, bins = 30, label = 'Binomial', alpha = 0.5, align = 'mid') # Binomial Distribution Means
pl.hist(chisq_means,bins=30, label = 'Chi-Squared', alpha = 0.5, align = 'mid') # Chisquared Distribution Means
pl.hist(lnorm_means, bins = 30, label = 'Lognormal', alpha = 0.5, align = 'mid') # Lognormal Distribution Means
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.legend(loc = 'best')
pl.title('Distribution of All Sample Means from Gaussian, Poisson, Binomial, Chi-Squared, & Lognormal')
# Out:
# Text(0.5,1,'Distribution of All Sample Means from Gaussian, Poisson, Binomial, Chi-Squared, & Lognormal')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 16: This is a histogram showing that frequency of all the sample means from the Gaussian, Poisson, Binomial, Chi-Squared, and Lognormal on one chart and how it hovers around 100 which is what was set in the beginning as the variable mymean for all the distributions.

# %% [markdown]
# # Extra Credit - Fit Gaussian to All Sample Means

# %%
# calculat gaus_means + pois_means + binomial_means + chisq_means + lnorm_means

all_means = gaus_means + pois_means + binomial_means + chisq_means + lnorm_means
pl.figure(figsize = (20,10))
seaborn.distplot(all_means, hist=True)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
# Out:
# Text(0,0.5,'N')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Figure 17: Pooling together all of the means from the Gaussian, Poisson, Binomial, Chi-Squared, and Lognormal distributions and fitting a Gaussian line.
